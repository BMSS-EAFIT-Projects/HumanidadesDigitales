# %%
import pandas as pd
import sys
import os

# Add the parent directory to sys.path so src can be imported
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import src.utils as utils

# %%
# Path relativo desde notebooks/ hasta data/raw/
ruta_corpus = "../data/raw/Corpus_completo_revisado.xlsx"

corpus_completo = pd.read_excel(ruta_corpus, engine="openpyxl")

# %%
corpus_completo
# Out:
#               Diario                       Autor               Fecha  \
# 0      El Espectador           Gonzalo Hernández  1 de enero de 2018
# 1      El Espectador    Eduardo Barajas Sandoval  1 de enero de 2018
# 2      El Espectador  Daniel Emilio Rojas Castro  1 de enero de 2018
# 3      El Espectador         Reinaldo Spitaletta  1 de enero de 2018
# 4      El Espectador             Aura Lucía Mera  1 de enero de 2018
# ...              ...                         ...                 ...
# 13671         Semana             Gonzalo Sánchez  4 de junio de 2019
# 13672         Semana              Álvaro Jiménez  3 de junio de 2019
# 13673         Semana                 Jairo Gómez  3 de junio de 2019
# 13674         Semana        Ana María Ruiz Perea  3 de junio de 2019
# 13675         Semana    Julián de Zubiría Samper  3 de junio de 2019
#
#                                                 Título  \
# 0                             Fajardo: para nada tibio
# ...

# %%
corpus_completo = utils.aplicar_funcion_fecha(corpus_completo)

# %%
corpus_completo
# Out:
#               Diario                       Autor      Fecha  \
# 0      El Espectador           Gonzalo Hernández 2018-01-01
# 1      El Espectador    Eduardo Barajas Sandoval 2018-01-01
# 2      El Espectador  Daniel Emilio Rojas Castro 2018-01-01
# 3      El Espectador         Reinaldo Spitaletta 2018-01-01
# 4      El Espectador             Aura Lucía Mera 2018-01-01
# ...              ...                         ...        ...
# 13671         Semana             Gonzalo Sánchez 2019-06-04
# 13672         Semana              Álvaro Jiménez 2019-06-03
# 13673         Semana                 Jairo Gómez 2019-06-03
# 13674         Semana        Ana María Ruiz Perea 2019-06-03
# 13675         Semana    Julián de Zubiría Samper 2019-06-03
#
#                                                 Título  \
# 0                             Fajardo: para nada tibio
# 1                                   Macedonia de Norte
# 2                   El nacionalismo según Vargas Llosa
# ...

# %%
path_processed = r"..\data\processed"

corpus_completo.to_excel(os.path.join(path_processed, 'corpus_date_formatted.xlsx'), index=False)

# %%
# %pip install spacy --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download es_core_news_lg --quiet
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')

# %%
import pandas as pd
import spacy

# %% [markdown]
# # Cargar corpus

# %%
file_path = r"C:\Users\karen\Documents\HumanidadesDigitales_git\BDD_Corpus\Corpus_completo_revisado.xlsx"
corpus_completo = pd.read_excel(file_path, engine='openpyxl')

# %%
# Formatear fechas

meses = {
    'enero': '01',
    'febrero': '02',
    'marzo': '03',
    'abril': '04',
    'mayo': '05',
    'junio': '06',
    'julio': '07',
    'agosto': '08',
    'septiembre': '09',
    'octubre': '10',
    'noviembre': '11',
    'diciembre': '12'
}

def convertir_fecha(fecha_str):
    partes = fecha_str.split(' de ')
    dia = partes[0].zfill(2)  # Asegura 2 dígitos para días 1-9
    mes = meses[partes[1]]
    año = partes[2]
    return f"{dia}/{mes}/{año}"  # Formato DD/MM/AAAA

corpus_completo['Fecha'] = corpus_completo['Fecha'].apply(convertir_fecha)
corpus_completo['Fecha'] = pd.to_datetime(corpus_completo['Fecha'], format='%d/%m/%Y', errors='coerce')

# %%
corpus_completo.head()
# Out:
#           Diario                       Autor      Fecha  \
# 0  El Espectador           Gonzalo Hernández 2018-01-01
# 1  El Espectador    Eduardo Barajas Sandoval 2018-01-01
# 2  El Espectador  Daniel Emilio Rojas Castro 2018-01-01
# 3  El Espectador         Reinaldo Spitaletta 2018-01-01
# 4  El Espectador             Aura Lucía Mera 2018-01-01
#
#                                Título  \
# 0            Fajardo: para nada tibio
# 1                  Macedonia de Norte
# 2  El nacionalismo según Vargas Llosa
# 3      Tiempo sagrado, tiempo profano
# 4           La rebelión de los bueyes
#
#                                                Texto  \
# 0  La Coalición Colombia –Partido Alianza Verde, ...
# 1  Las interpretaciones de la historia sirven com...
# 2  La semana pasada Mario Vargas Llosa publicó un...
# 3  Pudiera decirse, sin ser una verdad absoluta, ...
# 4  Lo mejor del encierro de Las Ventas fueron los...
#
#                                              Vínculo  ID
# 0  https://web.archive.org/web/20180102104221/htt...   1
# 1  https://web.archive.org/web/20180102104221/htt...   2
# 2  https://web.archive.org/web/20180102104221/htt...   3
# 3  https://web.archive.org/web/20180102104221/htt...   4
# 4  https://web.archive.org/web/20180102104221/htt...   5

# %% [markdown]
# # Reconocimiento entidades nombradas con spacy

# %%
nlp = spacy.load("es_core_news_lg", disable=["tagger", "parser"])

# %%
doc = nlp(corpus_completo['Texto'][2])

# %%
corpus_completo['Texto'][0]
# Out:
# 'La Coalición Colombia –Partido Alianza Verde, Polo Democrático Alternativo y Compromiso Ciudadano- presentó por fin a Sergio Fajardo como su candidato único a la Presidencia. \n\nFajardo diagnostica a Colombia como un país fracturado, indignado por la corrupción, despistado por no tener una agenda de desarrollo clara luego del boom minero energético, y “desambientado” en referencia al manejo de los recursos ambientales (http://sergiofajardo.co/).\n\nPromete un liderazgo hacia la reconciliación, una lucha intensa contra la corrupción y mejor educación como mecanismo para el fomento de una sociedad innovadora y emprendedora que pueda usar eficientemente sus capacidades. Reconoce abiertamente que la desigualdad -a nivel de las personas y de las regiones- es un obstáculo grande para una Colombia incluyente.\n\nLa energía y el énfasis de sus presentaciones sobre su visión del país inspiran y al mismo tiempo lo exponen, en ciertas ocasiones, a críticas por no presentar los detalles. En su más reciente entrevista en RCN Radio se vio contra las cuerdas. Tuvo que enfrentar acusaciones por su aparente tibieza y dio respuestas evasivas, en especial cuando se le preguntó si existía un acuerdo esencial con Jorge Enrique Robledo sobre el tema económico.\n\nEsto no debe, sin embargo, generar confusiones que lleven a caricaturizar a Fajardo con los sofismas tan apreciados por los promotores de la propaganda política vacía. Fajardo y su coalición han lanzado ya varias propuestas prácticas que incluso se convierten en dardos afilados que hieren los intereses de diversos grupos. Fajardo se ha atrevido a correr el riesgo de asumir un posible costo electoral que pocos asumen.\n\nManifestó su respeto a los acuerdos con las Farc. Anunció que no promete disminuciones de impuestos. Dijo que propenderá por una Dian fortalecida, pero no con el fin de justificar la promesa floja de que con un eventual recaudo más eficiente en el futuro se valida desde ya un desmonte de la carga tributaria. Cuestionó la más reciente reforma tributaria y descalificó su aparente tinte estructural. La base programática de su coalición plantea que propondrán una estructura de impuestos más progresiva -que ponga a pagar más a quienes más tienen- y el desmonte general de beneficios tributarios. Fajardo ha dicho que así como en su momento la sociedad colombiana asumió el impuesto para financiar la guerra tendrá que pagar ahora el impuesto para financiar la educación. En materia ambiental, promete, por ejemplo, instaurar una moratoria en la explotación tipo fracking. Y frente al álgido tema pensional, se ha mostrado a favor del aumento de la edad de jubilación como parte de una futura reforma. Nada tibio diría yo.\n\nPor supuesto, a este plan le faltan no uno sino dos hervores. Y tendrá que hervir en medio del frenetismo del sprint presidencial. Tienen que conectar y aterrizar las ideas para que el programa de gobierno de la coalición no quede débil y fracturado.\n\nMucho trabajo por delante para que Fajardo pueda hilar todos los cabos que, de quedar sueltos, pueden enredarle el camino en la fase de los debates. Mucho trabajo pedagógico por delante para convencer a un electorado que, por cuenta de la polarización, está acostumbrado a ver las cosas muy en blanco y negro.\n\nProfesor asociado de Economía y director de Investigación de la Pontificia Universidad Javeriana (http://www.javeriana.edu.co/blogs/gonzalohernandez/)'

# %% [markdown]
# ## Ejemplo visualización de las entidades en el texto

# %%
from spacy import displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">La semana pasada
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mario Vargas Llosa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  publicó una columna titulada El nacionalismo en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cataluña
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  en el diario peruano
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La República
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br><br>En ella sostiene que además de ser una « ideología ultrareaccionaria que crea ficciones para tergiversar la historia », el nacionalismo también es un acto de fé, opuesto a cualquier creencia en « la libertad, la democracia y la civilización ». En resumidas cuentas, y guardadas las proporciones, la visión que el escritor ofrece en su columna es muy similar a la que
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oscar Wilde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  resumió en la sentencia « el patriotismo es la virtud de los viciosos » (o de los deprabados).<br><br>La columna, y de forma general, todos los pronunciamientos del
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nobel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  desde que tuvo lugar el referendo independentista, buscan probar la insensatez del separatismo catalán. Su opinión, como la de muchos otros
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Españoles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Catalanes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  o la de todos aquellos que se oponen a cualquier atisbo de sentimiento nacional en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     los Estados
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  europeos, merece respeto.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El problema
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  es que su ataque a los independentistas justifica el nacionalismo español, con lo cual su visión crítica de ese ‘acto de fé’ opuesto a la ‘democracia’ pierde cualquier vigencia.<br><br>Como suelen sostenerlo otros críticos del independentismo, para
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vargas Llosa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  todo el problema se concentra en el nacionalismo catalán sin darle la más mínima importancia a la constitución de la nación española o a los problemas inherentes a su articulación política y territorial.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Por eso él y muchos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  otros presentan al independentismo como un exabrupto, sin imaginar que el
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Estado español
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  reposa sobre una pluralidad de soberanías regionales que pueden entrar en colisión. En una nación plural como la española, esas colisiones, sumadas a la legitimidad política de las regiones, pueden transformarse en reivindicaciones separatistas.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La responsabilidad del independentismo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  es compartida por
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     España
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y los
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Catalanes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , y no el fruto de un mero capricho de estos últimos, como pretende presentarlo el escritor.<br><br>Todas las dictaduras, nos dice
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vargas Llosa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , sean de izquierda o de derecha, han pretendido justificarse en argumentos nacionalistas.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Así lo ejemplifican los casos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fidel Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hugo Chavez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pinochet
#     <span style="font-size: 0.8em; f

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Coalición Colombia ORG
# Partido Alianza Verde ORG
# Polo Democrático Alternativo ORG
# Compromiso Ciudadano- MISC
# Sergio Fajardo PER
# Presidencia ORG
# Fajardo PER
# Colombia LOC
# Reconoce abiertamente que la desigualdad -a nivel de las personas MISC
# Colombia LOC
# RCN Radio MISC
# Jorge Enrique Robledo PER
# Fajardo PER
# Fajardo PER
# Fajardo PER
# Farc ORG
# Anunció ORG
# Dijo MISC
# Dian MISC
# Cuestionó MISC
# La base programática de su coalición MISC
# Fajardo PER
# Nada tibio diría yo.
#
#  MISC
# Fajardo PER
# Mucho trabajo pedagógico por delante para convencer a un electorado MISC
# Profesor asociado de Economía MISC
# Investigación de la Pontificia Universidad Javeriana ORG

# %% [markdown]
# ## NER para todo el corpus

# %%
# Lista para almacenar todas las entidades encontradas
todas_entidades = []

# Iterar sobre cada fila del dataframe
for idx, doc in enumerate(nlp.pipe(corpus_completo['Texto'])):
    # Procesar el texto con spaCy
    #doc = nlp(texto)
    
    # Obtener las entidades del documento
    for ent in doc.ents:
        # Crear tupla con toda la información requerida
        entidad_info = (
            ent.text,  # Entidad
            ent.label_,  # Label
            ent.start,  # Posición inicial (token)
            ent.end,  # Posición final (token)
            corpus_completo['ID'].iloc[idx],  # ID del documento
            corpus_completo['Título'].iloc[idx],  # Título del documento
            corpus_completo['Fecha'].iloc[idx],  # Fecha del documento
            corpus_completo['Autor'].iloc[idx]  # Autor del documento
        )
        todas_entidades.append(entidad_info)

# Crear el dataframe de entidades
entidades = pd.DataFrame(todas_entidades, columns=[
    'Entidad', 'Label', 'Posición inicio', 'Posición final', 
    'ID_col', 'Título_col', 'Fecha_col', 'Autor_col'
])

# Mostrar las primeras filas del dataframe resultante
print(entidades.head())
# Out:
#                         Entidad Label  Posición inicio  Posición final  \
# 0            Coalición Colombia   ORG                1               3
# 1         Partido Alianza Verde   ORG                4               7
# 2  Polo Democrático Alternativo   ORG                8              11
# 3         Compromiso Ciudadano-  MISC               12              14
# 4                Sergio Fajardo   PER               18              20
#
#    ID_col                Título_col  Fecha_col          Autor_col
# 0       1  Fajardo: para nada tibio 2018-01-01  Gonzalo Hernández
# 1       1  Fajardo: para nada tibio 2018-01-01  Gonzalo Hernández
# 2       1  Fajardo: para nada tibio 2018-01-01  Gonzalo Hernández
# 3       1  Fajardo: para nada tibio 2018-01-01  Gonzalo Hernández
# 4       1  Fajardo: para nada tibio 2018-01-01  Gonzalo Hernández

# %%
entidades.to_excel(r'C:\Users\karen\Documents\HumanidadesDigitales_git\Códigos\Out\entidades_spacy.xlsx', index=False)

# %%
entidades = pd.read_excel(r'C:\Users\karen\Documents\HumanidadesDigitales_git\Códigos\Out\entidades_spacy.xlsx')

# %%
entidades
# Out:
#                              Entidad Label  Posición inicio  Posición final  \
# 0                 Coalición Colombia   ORG                1               3
# 1              Partido Alianza Verde   ORG                4               7
# 2       Polo Democrático Alternativo   ORG                8              11
# 3              Compromiso Ciudadano-  MISC               12              14
# 4                     Sergio Fajardo   PER               18              20
# ...                              ...   ...              ...             ...
# 418529               Sagrado Corazón   LOC              588             590
# 418530                      Casanare   LOC              626             627
# 418531                     Venezuela   LOC              628             629
# 418532              De todas maneras  MISC              641             644
# 418533                      Colombia   LOC              659             660
#
#         ID_col                  Título_col  Fecha_col              Autor_col
# 0            1    Fajardo: para nada tibio 2018-01-01      Gonzalo Hernández
# 1            1    Fajardo: para nada tibio 2018-01-01      Gonzalo Hernández
# 2            1    Fajardo: para nada tibio 2018-01-01      Gonzalo Hernández
# 3            1    Fajardo: para nada tibio 2018-01-01      Gonzalo Hernández
# 4            1    Fajardo: para nada tibio 2018-01-01      Gonzalo Hernández
# ...        ...                         ...        ...                    ...
# 418529   13309  Casanare y el bicentenario 2018-12-28  Julio Londoño Paredes
# 418530   13309  Casanare y el bicentenario 2018-12-28  Julio Londoño Paredes
# 418531   13309  Casanare y el bicentenario 2018-12-28  Julio Londoño Paredes
# 418532   13309  Casanare y el bicentenario 2018-12-28  Julio Londoño Paredes
# 418533   13309  Casanare y el bicentenario 2018-12-28  Julio Londoño Paredes
#
# [418534 rows x 8 columns]

# %%
set(entidades[entidades['Label'] == 'PER']['Entidad'])
# Out:
# {'Fanny',
#  'Auxilio',
#  'Bolena',
#  'Miguel Gane',
#  'Paramilitar',
#  'Vuestra Excelencia',
#  'Kally Halloway',
#  'Luzma de Coscorrón',
#  'Gonzalo Castillo',
#  'Aló',
#  'Summers',
#  'Rodrigo Silva',
#  'López y Pérez',
#  'Goyo',
#  'Chejov',
#  'Carlos Bermeo',
#  'Valéry',
#  'Ernesto Sábato',
#  'Víctor Mosquera Chaux',
#  'fallecerían',
#  'Despotricar',
#  'Ciro Gomes',
#  'Caro',
#  'José Eusebio Otálora',
#  'Alfred Dreyfus',
#  'Acaba',
#  'Santiago Gamboa',
#  'Duque el Bicentenario de la Independencia',
#  'Dayro Moreno',
#  'Apagones',
#  'el Che de los Gais',
#  'Dumbledore',
#  'García Villegas',
#  'Diego Giacchino',
#  'Reynaldo',
#  'Deciden',
#  'Jorge Eliécer Gaitán. Ospina',
#  'Javier',
#  'ORT',
#  'David Ricardo',
#  'Luis Enrique Bacalov',
#  'Marcelo Cataldo',
#  'Paul Verlaine',
#  'Kelly Craft',
#  'Fredy Rendón Herrera',
#  'Beatrice',
#  'Gabriela Samper',
#  'Julio Gómez',
#  'Johanna Olaya',
#  'Susana',
#  'fei nius',
#  'Acomodados',
#  'María del Pilar',
#  'Cristina Pastrana Arango',
#  'Víctor Darío Luna',
#  'Jay Haas',
#  'David Melo',
#  'Johann Wolfgang von Goethe',
#  'Alberto Lozano',
#  'Rodrigo Duterte',
#  'Paolo Morais',
#  'Dora Luz Campo de Botero',
#  'Herodoto',
#  'Mijo',
#  'Huyssen',
#  'Benito Zambrano',
#  'Clausewitz',
#  'Adolfo Zableh',
#  'Dorys Ardila',
#  'Ramiro ‘Cuco’ Vanoy',
#  'Diego Rivera',
#  'Antonuela Ariza',
#  'Andrea Nieto',
#  'Alicia pa',
#  'Hidelgard von Bingen',
#  'condoler',
#  'Privilegie',
#  'Ryan Zinke',
#  'Shakira',
#  'Joseph Goebbles',
#  'Ivo Bracamonte',
#  'Friedrich von Hayek',
#  'Quiso',
#  'A Dreyfus',
#  'José Asunción Silva',
#  'Eric Establie',
#  'Juan Carlos Salazar',
#  'Marc',
#  'Luis Alberto González',
#  'Entidades',
#  'Jacques Attali',
#  'Joaquín Balaguer',
#  'Decía Rodolfo Rodríguez',
#  'William Klein',
#  'Oskar Kokoschka',
#  'Carlos Enrique Sánchez',
#  'Gustavo Mohar',
#  'Charles Mitten',
#  'Alberto Casas',
#  'https://bit.ly/2xkU7E6',
#  'Álvaro García Romero',
#  'Carlos Bernal Pulido',
#  'Beth',
#  'Cristina Marcano',
#  'Presidente Duda',
#  'Santoyo',
#  'Víctor Manuel',
#  'Blanca Barón',
#  'Dieb Nicolás Maloof Cuse',
#  'Ileana Ros-Lehtinen',
#  'Humberto Martínez',
#  'Aura Lucía',
#  'Diego Rastrojo o Vinagre',
#  'tac taaaaaac',
#  'Harold Muñoz',
#  'Macarrón',
#  'José Gregorio',
#  'Taiki MuraiGunther Schnabl',
#  'Segundo\n\n',
#  'Reírse',
#  'Muñoz',
#  'Fernando Franco',
#  'Clara y Caicedo',
#  'Concretamente',
#  'Samuel Huntington',
#  'Hacerlo',
#  'Dice Juan Esteban Constaín',
#  'Hernando Garzón Rey',
#  'Patadas',
#  'Vito Apushana',
#  'Acertó Presidente',
#  'Madre Patria',
#  'Loustau',
#  'Malestar',
#  'Prevenir',
#  'Carolina Moreno',
#  'Carlitos Puebla',
#  'Aníbal Martínez Zuleta',
#  'Recordemos',
#  'Tovar Jr',
#  'Simona Duque',
#  'Giraluna',
#  'David Cameron',
#  'Miraflores',
#  'Sergio Carlos Camargo',
#  'Siguen',
#  'Michaela Coel',
#  'Joan Báez',
#  'Eric Schmidt',
#  'Jan Steen',
#  'Delgado',
#  'Alejandro Moreno Sarmiento',
#  'José Hernández Aponte',
#  'Asoman',
#  'Leopoldo Marechal',
#  'Camilo Ortega',
#  'Microlingotes',
#  'Salomón Koppel',
#  'Albert Hirschman',
#  'Para Trump',
#  'Dudarles',
#  'Recep Tayyip Erdogan',
#  'Marco Fidel',
#  'M. Milankovitch',
#  'aderir',
#  'Edgar Morin',
#  'Camilo Montoya Reyes',
#  'Ramírez Arboled',
#  'Dale Ho',
#  'Daniel Defoe',
#  'martini',
#  'Michelle Bachelet',
#  'Benjamin Cardin',
#  'Martha Elena Toledo',
#  'Pueblito Viejo',
#  'Jairo Velasco',
#  'Cassiano',
#  'Silvano Serrano',
#  'Olvida Petro',
#  'Nian',
#  'Seth',
#  'Kiko',
#  'Oítes Marta',
#  'Expresar',
#  'William Ospina',
#  'Onganía',
#  'Pescó',
#  'Gilliam Armstrong',
#  'Castilla',
#  'Jeremías',
#  'Francisco Ricaurte Gómez',
#  'Óscar Wilde',
#  'Manuel María Flores',
#  'Max Von Sydow',
#  'Miguel García Sánchez',
#  'Lewis Coser',
#  'Samaniego',
#  'Lucía Ospina Ordóñez',
#  'María Vetsera',
#  'Fray Gabriel Flórez',
#  'Alí Primera',
#  'dotor Granados',
#  'Pregunté',
#  'María Laura Villalba',
#  'Darío Arizmendi',
#  'Carlos Mario Álvarez Morales',
#  'Apkinson',
#  'Santamaría Fundación',
#  'Susana Muhamad',
#  'Palocci',
#  'Rómulo Bustos',
#  'James Reston jr',
#  'Pete',
#  'Tanto Trump',
#  'Isabel Ramírez ´La muchacha´',
#  'Alejandra Torres',
#  'Fernando Gaviria',
#  'Gobierno-Eln',
#  'Prometían',
#  'Roland Huntford',
#  'Dueña',
#  'Hugo Mujica',
#  'Giorgione',
#  'Rafael Vergara',
#  'Alfredo Iriarte',
#  'Marcela Ascencio Medina',
#  'Antonio Gamoneda',
#  'Según Wolff',
#  'Alfie Dingley',
#  'Uribe— Cabal',
#  'Kavafis',
#  'Luis Carlos Sarmiento Gutiérrez',
#  'Superé',
#  'Wolfe',
#  'O. Henry',
#  'Ya Yesid Reyes',
#  'Gonzalo Córdoba',
#  'Denuesta',
#  'Clarke',
#  'James Lawrence King',
#  'Popcaan',
#  'Sofocles',
#  'José Fernando',
#  'Bret Stephens',
#  'Creatividá',
#  'El general Naranjo',
#  'A Barco',
#  'Según Daza',
#  'Luis Díaz Herodier',
#  'Otto Siegler',
#  'White',
#  'Jet-Set',
#  'Valentina',
#  'Javid',
#  'Uribe Celis',
#  'Pablo Ángel',
#  'Medidas',
#  'pechichón',
#  'Heimlich',
#  'Juan José Sebreli',
#  'Rosa María Palacios',
#  'Contó Barco',
#  'Robert Costa',
#  'Chatterton',
#  'Pilarín Bayés',
#  'Francesca',
#  'Harold Martina',
#  'Francisca',
#  'Santa Claus',
#  'Eliane Brum',
#  'Wilmer Castro Acuña',
#  'Jorge Dimitrov',
#  'Michel Platini',
#  'Diego Correa',
#  'Reinaldo Rueda',
#  'Noel',
#  'Javier Cáceres Leal',
#  'Nassar',
#  'uribe',
#  'Tatiana',
#  'Jorge Valdivia',
#  'Burgos Cantor',
#  'Aislarse',
#  'Vero',
#  'Pato Donald',
#  'Dentró',
#  'Almuerzo',
#  'Jaider Brochero',
#  'Cecilia Ramos Valencia',
#  'Enrique Grau',
#  'Gustavo Sierra Ochoa',
#  'Sarmiento Gutiérrez',
#  'Sujeto',
#  'Ulrika',
#  'Héctor Loboguerrero',
#  'Plagiando',
#  'Ideario',
#  'Edberto Guzmán',
#  'Alejandro Maya',
#  'Mia Farrow',
#  'juez Kennedy',
#  'Gilbert Berdine',
#  'Nubank',
#  'Empujan',
#  'Pablo',
#  'Repetían',
#  'Lucía Liévano',
#  'Simpatizaron',
#  'Bernie',
#  'Checo Acosta',
#  'Abandonarla',
#  'Como vamos',
#  'De Roux',
#  'Joaquín Sorolla',
#  'San José',
#  'bolivariano',
#  'Guillermo Buitrago',
#  'Deissy Rodríguez',
#  'Ariza Lascarro',
#  'María Mónica',
#  'José Jair Cortés',
#  'Consuelito',
#  'Filolao',
#  'Charroux',
#  'Kavanaugh',
#  'Robert Schumann',
#  'tatequieto',
#  'Potiorek',
#  'Murdoch',
#  'El señor Peñalosa',
#  'Oscar Muñoz',
#  'Santiago Silva',
#  'Carrero',
#  'Armando Novoa conceptúan',
#  'Segundo Decenio de Acción',
#  'Tienes',
#  'Luis Ospina Vásquez',
#  'Jacques Prévert',
#  'Manuel Antonio López Obrador',
#  'Sergio Vargas',
#  'Joseph Schumpeter',
#  'Florentino Pérez',
#  'Juan Carlos de España',
#  'Faustino Asprilla',
#  'Ana Tijoux',
#  'Gutiérrez Sanín',
#  'Roberto Abbondanzieri',
#  'Arthur Miller',
#  'Frakin Covidio',
#  'Gabriele Berg',
#  'Rafael Videla',
#  'Frank Holguín Ortiz',
#  'María Soledad',
#  'Felipe Ríos de Cambio Radical',
#  'Corleone',
#  'Alberto Olmos',
#  'Guarumo',
#  'Jonatan Agudelo',
#  'Joseel Duván Ibarra',
#  'Darío Echandía Olaya',
#  'GRACIAS POR TANTO',
#  'William Roberto Medina',
#  'Jaime Vidal Perdomo',
#  'Chonto Ortiz',
#  'Bohórquez',
#  'resentment',
#  'Expresidente',
#  'Luis Daniel González',
#  'Quitasueño',
#  'Suso',
#  'Luis Sáez Rueda',
#  'Peirce',
#  'Laura Restrepo',
#  'Michiko Shoda',
#  'Davies',
#  'Pobres J. M. Coetzee',
#  'Ángela María Robledo',
#  'Carlos Cuauhtémoc Sánchez',
#  'Son dos',
#  'Adriana Falcón',
#  'Fernando Monetti',
#  'Ignacio Lula da Silva',
#  'Taira',
#  'Según Saviano',
#  'Tarde',
#  'Carlos Fortín',
#  'vas pal allanamiento',
#  'Scott McNealy',
#  'Gonzalo Jiménez de Quesada',
#  'Hugo de Jesús Tamayo Gómez',
#  'gribenes',
#  'Uri Geller',
#  'Khashoggi',
#  'Canelo Álvarez',
#  'Iván Marulanda',
#  'Carlos Rojas',
#  'Bernays',
#  'Juan de Castellanos',
#  'Valery Gergiev',
#  'Carlos Navia',
#  'sons',
#  'Santos Calderón',
#  'Oites Marta',
#  'Frantz Fanon',
#  'Betancourt',
#  'José Villa Soberón',
#  'José Salgar',
#  'Jaime Orlando Santofimio',
#  'Deas',
#  'José Domingo Granados Jiménez',
#  'Planeación Distrital',
#  'Prometeo',
#  'Estrabón',
#  'Karen Granados',
#  'Tirole',
#  'Asprilla',
#  'Camilo Bula',
#  'Chapeau',
#  'Felipe ‘Los Tolimenses’',
#  'Mary Luz Herrán',
#  'George R. R. Martin',
#  'Coutinho',
#  'señor Gerlein',
#  'Dragados',
#  'Arafat',
#  'Rodolfo Segovia Salas',
#  'Arleth Casado de López',
#  'Moritz Schularick',
#  'María Valencia',
#  'Rodrigo Díaz de Vivar',
#  'Verbo',
#  'María Ángela Holguín',
#  'Pepe Sánchez',
#  'Poder. Nutrimos',
#  'Arsenio',
#  'Darío Betancourt',
#  'Aldemar Rojas',
#  'Pablito Flórez',
#  'Murciélago',
#  'Pedro Pablo',
#  'martín pescador',
#  'Dividen',
#  'Camille',
#  'Saramago',
#  'Roger Waters',
#  'Tuve',
#  'Alfonso Borrero',
#  'Falcao García',
#  'Luis Carlos Restrepo',
#  'Fanor Mondragón',
#  'Juan Gabriel Tokatlián',
#  'Cristian Camilo Bellón',
#  'Beethoven',
#  'Kriss Urueta León',
#  'Fanny Patricia Guerra Gómez',
#  'Carlos Albino',
#  'Juan Sebastián Aragón',
#  'Reducirlas',
#  'Mersenne',
#  'Jack el Destripador',
#  'Miren tías',
#  'Emilio Echeverri',
#  'Simei',
#  'Juan Pablo Montoya',
#  'San Roque',
#  'Sandra',
#  'autoalabanza',
#  'tuiter',
#  'Vasti',
#  'Sabrán esto Duque',
#  'Según Salazar',
#  'Beaumont',
#  'Enrique Camacho',
#  'Hicieron',
#  'Peregoyo',
#  'Alicia Bárcena',
#  'Ali Abdullah Saleh',
#  'Cremoleta',
#  'Graves',
#  'Desarmadas',
#  'señor Reagan',
#  'Andrea',
#  'Mahmud Ahmadineyad',
#  'Don Alveolo',
#  'Nonato Cañola',
#  'Nicolás García Bustos',
#  'Lam',
#  'Anastasio Somoza Debayle',
#  'Gita Gopinath',
#  'María',
#  'Lamb',
#  'Alberto Duque López',
#  'Hirata',
#  'Leonardo Medina',
#  'Guy Debord',
#  'Carlos Enrique Moreno',
#  'Rubén Darío Molano',
#  'Camilo Torres Restrepo',
#  'Sackler',
#  'Eustasio de la Torre Narváez',
#  'A Ordine',
#  'Veni',
#  'Benjamin Griveaux',
#  'Orlando Molano',
#  'Primo Levi',
#  'Bernardo Ñoño Elías',
#  'Nicolás Osorio',
#  'Nancy García',
#  'Luisa Santiaga',
#  'Emanuel Echeverri',
#  'Guillermo Cajiao Lenis',
#  'Jorge Sampaoli',
#  'Ishiba',
#  'Ezequiel',
#  'Zé Rubem',
#  'Eche',
#  'Teresita Melo',
#  'Llanedt Martínez',
#  'María Catalina Colmenares',
#  'Surivaka',
#  'María Mónica Monsalve',
#  'Eugénie Bouchard',
#  'Joseph Pulitzer',
#  'Fresia Ochoa',
#  'Melba Escobar',
#  'Dora Franco',
#  'Vicente y María',
#  'Corzo',
#  'A Garzón',
#  'Máximo Kirchner',
#  'Antonio Ortuño',
#  'Quemar',
#  'Jörg Haider',
#  'Gógol',
#  'Alejandro Roca',
#  'Uf',
#  'Eduar Mauricio Rodríguez',
#  'Helena Urán',
#  'Libardo Orozco',
#  'Para el Libertador',
#  'Coyunturas',
#  'A Obama',
#  'Conchita Cintrón',
#  'Víctor Frankenstein',
#  'Pablo González',
#  'Lenin',
#  'sumirían',
#  'Ezequiel Uricoechea',
#  'Baselga',
#  'Christian Padilla',
#  'Alejandro Sánchez',
#  'González',
#  'Wilmer González',
#  'Joaquín Gómez',
#  'Uribe III',
#  'Antonio Zabaraín',
#  'Jorge Orlando Melo',
#  'Alberto Rojas',
#  'José Guillermo Medina Sánchez',
#  'Pecaut',
#  '@fruandes',
#  'McConnell',
#  'Estanislao',
#  'Gerald Foos',
#  'Néstor Elí',
#  'Pedrito',
#  'Honka Monka',
#  'Joaquín Robles Zabala',
#  'Lawrence Douglas',
#  'Jordan',
#  'Verónica Carrasquero',
#  'Fasecolda',
#  'Puja',
#  'general Silva',
#  'el Chontico',
#  'Francisco Ordóñez',
#  'Tognato',
#  'Lina Galíndez',
#  'Compañeras',
#  'Sr. Condorcet',
#  'Diana Ospina',
#  'Tomas Surí Salcedo',
#  'Míralas',
#  'Colosó',
#  'El señor Londoño Mejía',
#  'Andrés Valencia',
#  'Lee Harvey Oswald',
#  'Fernando Meirelles',
#  'Vargas Lleras-Viviane',
#  'Heredó',
#  'Claude Monet',
#  'Chonto',
#  'Rousseau',
#  'Owen',
#  'Menor',
#  'George Papadopoulos',
#  'Edward Bernays',
#  'Jhon Arley Murillo',
#  'Óscar Ivan Zuluaga',
#  'Cristina Ochoa Vásquez',
#  'Lourdes',
#  'Querámoslo',
#  'María Angélica Bernal',
#  'delgado',
#  'Valdés',
#  'inflexibilidades',
#  'Alvin Hansen',
#  'Bellini',
#  'Juana Dávila',
#  'Alcide de Gasperi',
#  'A Carlos Gaviria',
#  'Thomas Van der Hammen',
#  'Hernán Andrade',
#  'Diego García-Sayán',
#  'Jacobo Arenas',
#  'Sobraría',
#  'Abreu',
#  'Angelici',
#  'Allen Hicken',
#  'Juan Arcila',
#  'Cuvier',
#  'Rolando Avendaño',
#  'Lacalle',
#  'Candé',
#  'der',
#  'Geovanni Banguera',
#  'CaMINA',
#  'Newt Gingrich',
#  'Cuandoquiera',
#  'Fermina Daza',
#  'Hobsbawm',
#  'Lucero Cortés',
#  'líbranos Señor',
#  'Chimamanda',
#  'Fratelli',
#  'Saoirse Ronan',
#  'Alexis de Tocqueville',
#  'Pobladolife',
#  'Reema Bandar al-Saud',
#  'Genuinamente',
#  'Cozy Bear',
#  'Willem Dafoe',
#  'Julián Rodríguez',
#  'Morricone',
#  'Camilo Uribe Uribe',
#  'Carlos Arturo Romero Jiménez',
#  'Leidy Díaz',
#  'Hugh Thomas',
#  'George W. C. Bush',
#  'Kike Peñalosa',
#  'Germán Trujillo',
#  'Juan Pablo II',
#  'Morin',
#  'Nicolás Guillén',
#  'milagrerías',
#  'Eduardo Cabrera',
#  'Eduardo Stein',
#  'Rocio Arias Hofman',
#  'Hugo Alberto Buitrago',
#  'boquiabierto',
#  'Urge',
#  '5.- Reorganizar',
#  'Lyons',
#  'Aceleró',
#  'Rudolf Hommes',
#  'Ruby Marcela Pérez',
#  'Nhora',
#  'Odebrecht-Sarmiento',
#  'Álvaro Uribe Vélez Colombia',
#  'Llovía',
#  'Harold Bloom',
#  'María José Pizarro',
#  'Muhammad Ali',
#  'María Fernanda González',
#  'Alberto Garrido',
#  'Sanders',
#  'Rosario López Romero',
#  'Minhacienda Carrasquilla',
#  'Píccolo',
#  'Esther Lozano Alfaro',
#  'páguese',
#  'Vargas Lleras',
#  'Subirá el sol',
#  'Thompson',
#  'Luis Guillermo Vélez',
#  'Bono',
#  'Óscar Ruiz',
#  'Rees',
#  'Desamores',
#  'Óscar de León',
#  'deteni da.',
#  'Jean Pierre Bemba',
#  'Thatcher-Reagan',
#  'Su-sanita',
#  'Pardo',
#  'Romer',
#  'Rodrigo Bentancur',
#  'Boris',
#  'vastedades',
#  'Giscard d’Estaing',
#  'Napoleón III',
#  'Aznar',
#  'Erwin Arias',
#  'Petro',
#  'Luis Alberto Villegas Uribe',
#  'Alejandro Saavedra Cardona',
#  'Horrorizado',
#  'Javier Ortega',
#  'Luis Palacios',
#  'Sam Mendes',
#  'Yu',
#  'Márai',
#  'Jorge Luis Ortega',
#  'Sire',
#  'Manda',
#  'reventarían',
#  'Yamamoto',
#  'Vasili Grossman',
#  'Nicolás Isaksson',
#  'cundían',
#  'Gabriel Mesa',
#  'Juan Manuel Renjifo',
#  'Dictaba',
#  'Ismenia Marmolejo',
#  'Víctor Ortiz',
#  'Miguel Ceballos',
#  'Nacho López',
#  'Rue',
#  'Agustín Lara',
#  'Alberto Chimal',
#  'Calderón',
#  'Saco',
#  'Veloso',
#  'Antonio García',
#  'Casilda Zafra',
#  'Gorgona',
#  'Mais',
#  'Eloisa',
#  'Le',
#  'Mateu Lahoz',
#  'Jean-Pierre Sergent',
#  'Martinelli',
#  'Wayne Williams',
#  'Guillén',
#  'Origo',
#  'Bonaria',
#  'Adam Smith Institute',
#  'William Aranguren',
#  'Blasón',
#  'Catherine Ibarguen',
#  'Walter White',
#  'Bernie Sanders',
#  'Rihanna',
#  'Sacrifixio',
#  'Marçal',
#  'Luis Fernando',
#  'Antonio José Urdinola',
#  'Carlos Antonio Lucio. Navarro',
#  'Jeffrey Tucker',
#  'Cho Chop',
#  'Farc-ep',
#  'Tolita',
#  'Clint Eastwood',
#  'Doctor',
#  'Nesticor Humberto',
#  'Jairo Libreros',
#  'Luis Miguel Cotes',
#  'Juan Esteban',
#  'García Herreros',
#  'Antemio de Tralles',
#  'Ekatelini',
#  'Miguel de la Espriella',
#  'Norman Borlaug',
#  'Pepa',
#  'Albeiro Gallego',
#  'João Doria',
#  'Ian McEwan',
#  'J. Vermeer',
#  'Madrugaré',
#  'Mario de Jesús Álvarez',
#  'Al',
#  'Alejandro Chacón',
#  'William Villamizar',
#  'Pandolfini',
#  'Eljach',
#  'Marisol Gómez',
#  'Marta Ruiz',
#  'Yesid Vázquez Prada',
#  '¨a Uribe',
#  'Germán Escobar',
#  'Ra',
#  'Imer Machado',
#  'Ñapa: Tola',
#  'Encabeza',
#  'Kogui',
#  'J. A. Osorio',
#  'Lutero',
#  'Eros',
#  'Nicolasa Ibáñez',
#  'Laura Robles',
#  'Ximena Ochoa',
#  'Hudson',
#  'Infante',
#  'Coronel de García Márquez',
#  'Hofstadter',
#  'McNamara',
#  'Mayren',
#  'marica',
#  'Jane Eyre',
#  'Zuluaga Peña',
#  'Ettore Scola',
#  'Adicional',
#  'Cucho',
#  'Thomson',
#  'Dilian Francisco Toro',
#  'Neftalí',
#  'Caín',
#  'Daniel Martínez',
#  'Héctor Fabio Murillo',
#  'San Alfonso María de Ligorio',
#  'James Kirkpatrick Stewart',
#  'Ananías',
#  'McDermott',
#  'Sara',
#  'Alonso Ríos Vanegas',
#  'Yesenia Zamudio',
#  'Entonces Coetzee',
#  'Jaime',
#  'José Granados para Zona Cero.com',
#  'Osvaldo Consuegra',
#  'biólogas',
#  'Pensarías',
#  'Carlos Carrillo',
#  'José Aguirre',
#  'Ficus Religiosa',
#  'Estraval Carlos Mondragón',
#  'Pescarán',
#  'José White',
#  'Imaginan',
#  'León Fredy Muñoz',
#  'Enrique Ampudia',
#  'Sinfónica Simón Bolívar',
#  'María Fernanda Rojas',
#  'Desfallecemos',
#  'Marina',
#  'Coelho',
#  'Eva',
#  'Mario José Carvajal',
#  'Sánchez Cordero',
#  'Thierry Breton',
#  'EJC1136',
#  'Monsalve',
#  'Gamal Abdel Nasser',
#  'Giuliano Montaldo',
#  'Domingo',
#  'John Wesley Hyatt',
#  'Sintraimagra',
#  'ASAB',
#  'Allison Becker',
#  'Fecolsog',
#  'Decía Bolívar',
#  'Roland Valero',
#  'Benjamin',
#  'Ápkinson',
#  'Cleofás Pérez',
#  'Fuera Rajoy',
#  'Yankel',
#  'resucito',
#  'J. Michell',
#  'Jean-François Revel',
#  'Propinó',
#  'Yad Vashem',
#  'Hahn',
#  'Camila Henríquez Ureña',
#  'Ehud Olmert',
#  'José Henrique Mariante',
#  'Esap Publicaciones',
#  'Mutsuhito',
#  'Bansky',
#  'Andrew Selee',
#  'Ana María Vega Rangel',
#  'Meursault',
#  'Stevens',
#  'Keiko Fujimori',
#  'Lopetegui',
#  'Laura Moreno',
#  'Comte',
#  'Amenazas',
#  'Eva Illouz',
#  'James Escobar',
#  'Perspicaz',
#  'Ron Viejo',
#  'Rudecindo Castro Hinestrosa',
#  'Carlos F. Chamorro',
#  'catalina Uribe',
#  'James Windle',
#  'madame Verdurin',
#  'Jeenbúdá',
#  'Alexa',
#  'Robert Lucas',
#  'Mario Lamo',
#  'Morimos',
#  'Carmen Balcells',
#  'Philip Seymour Hoffman',
#  'Ché Sudaka',
#  'Leonardo da Vinci',
#  'Bartolomé Calvo',
#  'Sainte-Beuve',
#  'Jorge Pinzón',
#  'Condesciende',
#  'Alberto Mejía',
#  'Shinzo Abe',
#  'Engañaron',
#  'Feo',
#  'Luis Fernando Camacho Vaca',
#  'Busqué',
#  'Montella',
#  'Ante Félix',
#  'Jean Bédel Bokassa',
#  'Idéntica',
#  'Junté',
#  'Dice Mandino',
#  'Mercedes –La Cubanita',
#  'José Díaz',
#  'Habsburgo',
#  'David Bargal',
#  'descrestan',
#  'Pastrana Arango',
#  'Casa de Tudor',
#  'José Carreras',
#  'Imitémoslos',
#  'Castro-Chavismo',
#  'Andrea Coi',
#  'Fernando Ojalvo',
#  'Brad Davis',
#  'Mussolini',
#  'Nilufer Demir',
#  'Manuel Zapata',
#  'Salinger',
#  'Nancy González',
#  'Alekos Alavanos',
#  'Resaltar',
#  'Emma Bovary',
#  'Alejandro Almazán',
#  'Dinero',
#  'Gerardo Ardila',
#  'Renato Cisneros',
#  'Lina Cuéllar',
#  'El Ideam',
#  'NiUnoMenos',
#  'Ole Memo',
#  'Perdón señores RAE',
#  'Arango Correa',
#  'Iván Duque. Paga',
#  'Tulio Patrón',
#  'Desempolvémoslo',
#  'Richard Epstein',
#  'Robert Mueller',
#  'Guayacanal',
#  'Doña Flor',
#  'Pastrami',
#  'Arturo',
#  'Biao',
#  'Clotilde',
#  'Barreto Escobar',
#  'Carolina Herrera',
#  'Trump-Santos',
#  'Jotamario Valencia',
#  'Diego de Ordás',
#  'Reto',
#  'Luis Alfredo Garavito Cubillos',
#  'Bulgakov',
#  'Wílser Darío Molina Molina',
#  'P. S. Sí',
#  'Doctor Gaviria',
#  'digerían',
#  'José Fernando López',
#  'Tinigua',
#  'José Manuel Pérez',
#  'pei',
#  'Alfredo Ramos Amaya',
#  'Poveda',
#  'Sands',
#  'Francisco I de Francia',
#  'Frédéric Martel',
#  'Leyendo',
#  'Francisco Javier',
#  'Michelle Goldberg',
#  'Bargüil',
#  'Ruth Ben-Ghiat',
#  'Arthur Percival',
#  'Zolima Montes',
#  'Fuad',
#  'José Felis trinó',
#  'Kruschev',
#  'Ovidio',
#  'Totó',
#  'Gutenberg',
#  'Boris Jonhson',
#  'Óscar Arias',
#  ...}

# %% [markdown]
# # Reconocimiento de entidades con GLiNER

# %%
# %pip install gliner --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import transformers
from gliner import GLiNER

model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# c:\Users\karen\anaconda3\Lib\site-packages\transformers\convert_slow_tokenizer.py:562: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
text = corpus_completo['Texto'][164]
#text = corpus_completo['Texto'][4143]

labels = ["persona", "organizacion", "lugar", "obra_de_arte", "lugar_literario", "escritor", "otra"]
entities = model.predict_entities(text, labels, threshold=0.5)


for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# c:\Users\karen\anaconda3\Lib\site-packages\gliner\data_processing\processor.py:351: UserWarning: Sentence of length 408 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# García Márquez => escritor
# Aracataca => lugar
# Macondo => lugar_literario
# Faulkner => persona
# Yoknapatawpha => obra_de_arte
# Nicolás Ricardo Márquez Mejía => persona
# Aracataca => lugar
# Jorge Eliécer Gaitán => persona
# Cámara de Representantes => organizacion
# Aracataca => lugar
# United Fruit Company => organizacion
# García Márquez => escritor
# Plinio Apuleyo Mendoza => persona
# El olor de la guayaba => obra_de_arte

# %%
text = corpus_completo['Texto'][4143]

labels = ["persona", "organizacion", "lugar", "otra"]
entities = model.predict_entities(text, labels)

for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# c:\Users\karen\anaconda3\Lib\site-packages\gliner\data_processing\processor.py:351: UserWarning: Sentence of length 601 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# Nicanor Parra => persona
# Perón => persona
# Getúlio Vargas => persona
# Carlos Ibáñez => persona
# Estados Unidos => lugar
# Allende => persona
# Pagu => persona
